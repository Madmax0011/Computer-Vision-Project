# %% [markdown]
# # Introduction
# This colab worksheet provides a starting point for the computer vision assignment.

# %% [markdown]
# # Data Loading

# %%
# Download the data stored in a zipped numpy array from one of these two locations
# If you're running all your experiments
# on a machine at home rather than using colab, then make sure you save it
# rather than repeatedly downloading it.

# !wget "https://sussex.box.com/shared/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo" -O training_images.npz

# The test images (without points)
# !wget "https://sussex.box.com/shared/static/i0apaktucm7y4od7k4ux69k8t1iue7w8" -O test_images.npz

# The example images are here
# !wget "https://sussex.box.com/shared/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a" -O examples.npz
# Out:
# --2024-05-15 09:59:17--  https://sussex.box.com/shared/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.144
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo [following]
# --2024-05-15 09:59:18--  https://sussex.box.com/public/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo [following]
# --2024-05-15 09:59:18--  https://sussex.app.box.com/public/static/eb9cfqjn82zpzwjgfq5vqvg07t3aiqwo
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.144
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!rkp9ju0m8tG3sgvUnmFXGWgTA07xfzRxxtnF0xiOyLP-Y4iU7IHlQ8znqov1D46qDcsLO2zi8OUWG4Oip1umsmbtyyUxJ7ffREs2Iq85CeGm5ubkHsUor4WJlwaT7-j1C9C5kU1g47QVUM5NgZ0S9SjPk1U6ZRRuACvFv16gF3WzN8ReLJvUvlxoxyXouY0_jkS6eS38curUXXZaR05WvPP19HNRaY7O0jfdHhWFgnRksK0mTjY01QFut2urAiWjHom1BHS3dqqzmIAbRAYAtl1WLlbE1uY7t3uyWh2QFl9uU3_jSXs9LgbpIwTTfp9Dcup5V5YTTP4rJOqZMFI6iGwG96mkdxJtOKcoy0Qr6Wyvi8l8xnoMVb9cTZ8aHIwoJf5oxZ2CCaHfw6ZNRYEUcYNvRb9QsRQ_rdDtcZCm-GcHTJvZfdGO63JpVFE9gflNZHBQBNLPdeGNvbzF0oSuxyTRqOsP8UPoR27e-kZMb8QvGRcwQLMxaL4i8aBEwz_G0qA1XpONyxOo57WeAC3gajPbaUNEFUZDSStVbaabhUta9SiiDqhpVKatVEi1uijvfbN5nyAczNpNe-aaQOs0jvC6Bv-X8j8jDijscDbE02eQ7xYB0ikL7oQFlFW9MhyeSCqIDFEwN7griLJ8EJu1TqA4Bto2n4cQwoI59UoDcYF7BpInLAfxxh5YjECjKDSfKl5MuBMI5u2GGZVNI-qOEUdHC_1GP93ghE-ZrSjpMYZiBxg5qnPYFHu7OvYjjWh4CrkeyAxhjHlBxYAnmX_gPf3oDmc29B_QwuvUPKpDOvIX0DJHoYeZvD7JRM8Y6MM7hVMbVE9EslTrz5azHXL87DUZi4i0l59kesCMSCDYGrxBp4WCCUORc8Ia7W2TE0PZqTOsbE0zHHkhHMSClSpoXIBgsqAToAqNhrs-noK8hUA_t2QxIElZKxsOCveKo_k4JPpUPwCO9EqEWbgOxWk9MeNIySrjy4TTuK3fC5XLKWnR8IsI1etk2jS8Jn1KNK5mzFonO56mitO69RoarmE3APKJxJ8j7awlb3PRfJSuKRdNXarOvF0GN4h_HH_3hm4eV8XCsXyGU293B8jc4BTQXGc8x75V2sM8Y5w7C9BiXEu16ezEj3zM2yt4Z2wZkdgxsdpsxaFopbYGh__j1jDHMO7jTaKKg81Y9gpiQ_nW9EW2mprayfXnis8iijbbD72XbAyUSeEPXWFQSehuKzUVQSuZ4KTGj_F-puua1r6lUwjA31Nxhrw1O_4AejWPQQ3ZVVNdRTcL5cWAKPrOOTMSy6zdATlAuR-EloMAKTQN_1RRp--gtjvd3fJsCUb-EXDyTBcpTiKfKxXgBF2ZghRErGVCfCFEnyaWhq7ZR-ANX5Z4vZ6bI_SHW6x4ltTMcwhPIYZWtgvtL0DgLWb0PzBL0_1oF4mC/download [following]
# --2024-05-15 09:59:18--  https://euc1.boxcloud.com/d/1/a1!rkp9ju0m8tG3sgvUnmFXGWgTA07xfzRxxtnF0xiOyLP-Y4iU7IHlQ8znqov1D46qDcsLO2zi8OUWG4Oip1umsmbtyyUxJ7ffREs2Iq85CeGm5ubkHsUor4WJlwaT7-j1C9C5kU1g47QVUM5NgZ0S9SjPk1U6ZRRuACvFv16gF3WzN8ReLJvUvlxoxyXouY0_jkS6eS38curUXXZaR05WvPP19HNRaY7O0jfdHhWFgnRksK0mTjY01QFut2urAiWjHom1BHS3dqqzmIAbRAYAtl1WLlbE1uY7t3uyWh2QFl9uU3_jSXs9LgbpIwTTfp9Dcup5V5YTTP4rJOqZMFI6iGwG96mkdxJtOKcoy0Qr6Wyvi8l8xnoMVb9cTZ8aHIwoJf5oxZ2CCaHfw6ZNRYEUcYNvRb9QsRQ_rdDtcZCm-GcHTJvZfdGO63JpVFE9gflNZHBQBNLPdeGNvbzF0oSuxyTRqOsP8UPoR27e-kZMb8QvGRcwQLMxaL4i8aBEwz_G0qA1XpONyxOo57WeAC3gajPbaUNEFUZDSStVbaabhUta9SiiDqhpVKatVEi1uijvfbN5nyAczNpNe-aaQOs0jvC6Bv-X8j8jDijscDbE02eQ7xYB0ikL7oQFlFW9MhyeSCqIDFEwN7griLJ8EJu1TqA4Bto2n4cQwoI59UoDcYF7BpInLAfxxh5YjECjKDSfKl5MuBMI5u2GGZVNI-qOEUdHC_1GP93ghE-ZrSjpMYZiBxg5qnPYFHu7OvYjjWh4CrkeyAxhjHlBxYAnmX_gPf3oDmc29B_QwuvUPKpDOvIX0DJHoYeZvD7JRM8Y6MM7hVMbVE9EslTrz5azHXL87DUZi4i0l59kesCMSCDYGrxBp4WCCUORc8Ia7W2TE0PZqTOsbE0zHHkhHMSClSpoXIBgsqAToAqNhrs-noK8hUA_t2QxIElZKxsOCveKo_k4JPpUPwCO9EqEWbgOxWk9MeNIySrjy4TTuK3fC5XLKWnR8IsI1etk2jS8Jn1KNK5mzFonO56mitO69RoarmE3APKJxJ8j7awlb3PRfJSuKRdNXarOvF0GN4h_HH_3hm4eV8XCsXyGU293B8jc4BTQXGc8x75V2sM8Y5w7C9BiXEu16ezEj3zM2yt4Z2wZkdgxsdpsxaFopbYGh__j1jDHMO7jTaKKg81Y9gpiQ_nW9EW2mprayfXnis8iijbbD72XbAyUSeEPXWFQSehuKzUVQSuZ4KTGj_F-puua1r6lUwjA31Nxhrw1O_4AejWPQQ3ZVVNdRTcL5cWAKPrOOTMSy6zdATlAuR-EloMAKTQN_1RRp--gtjvd3fJsCUb-EXDyTBcpTiKfKxXgBF2ZghRErGVCfCFEnyaWhq7ZR-ANX5Z4vZ6bI_SHW6x4ltTMcwhPIYZWtgvtL0DgLWb0PzBL0_1oF4mC/download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.135
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 391815893 (374M) [application/octet-stream]
# Saving to: ‘training_images.npz’
#
# training_images.npz 100%[===================>] 373.66M  24.2MB/s    in 16s
#
# 2024-05-15 09:59:35 (22.9 MB/s) - ‘training_images.npz’ saved [391815893/391815893]
#
# --2024-05-15 09:59:36--  https://sussex.box.com/shared/static/i0apaktucm7y4od7k4ux69k8t1iue7w8
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.144
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/i0apaktucm7y4od7k4ux69k8t1iue7w8 [following]
# --2024-05-15 09:59:36--  https://sussex.box.com/public/static/i0apaktucm7y4od7k4ux69k8t1iue7w8
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/i0apaktucm7y4od7k4ux69k8t1iue7w8 [following]
# --2024-05-15 09:59:36--  https://sussex.app.box.com/public/static/i0apaktucm7y4od7k4ux69k8t1iue7w8
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.144
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!z_khLHUoRctaMmLlP5dzQ30u3x4hbwFJNOCqskgw5yoNJ1uOPwzXDWLI7FvD0D7TdWt2rJ3FHap6zemcF7sUqKd48FPrLT_QQUJ3M8JxXUCRRY4RNd-szlO3RFA03jcDWTK0SwQcHio3u_P9ub8Bvn1PDc2GvCsfSRqqur-4AZhjIZDLGiVn5mLV8knP4O5uWnorkO2ZqpNIZOvoj0nqH91P1hy5Jfrxfu093_yadsdZFjPKMsUDNd7L1m1aX7A6UTFJ1t_mhYpayur0RCkmSoZgWdwci3BnRMcVUNpKHxIfjMWlIQDhk1Xicg1gEmlr4cCcfwcjWN0j6MR9DDptt36szlVAbMPEy0DodTEUUpjXPg2HLeqTsV3k01sdW7KEEbCwnynKHHccNpRk4ilyN3WyX4EpAb1wkR6o7sDM_84juVH1p8fC9v6Wq4rYxRyPnYz5DFdRCgNN0MA2DvlFaIXbcBNg5IwTqnra932v3f85rLU1yywT-E-EcoIPfSTNFfmXWztdJnqVkWMngijGFSw6NznJPKu48Kj0TlHYIaqlUDSmUqneMICIK_g4l1xV_jtgHYLZQ0vYn_Eh8hqAmXx2XFGdnX3qXOEJwcUiu6tAPlwBToQfbqcz6CFkkz6e7JatbQT4aJK7xZKEPHat6szmKAFPdPE26-WI-ReNtkAt_ql3N90EN2ameA-3KVtvdUENoeI-k5s4iukzzciqi3Wfjcxdw5EUWjgumU4g-_2CP0GiZyyKqzq4y5e73CRmEA1srjP5J-23FStxt7ZbbUEYyfNmMJehAt2h8CqneDbEwGG0zw_sSNj0MhpFenHznxoAFyQMo79i47pjpbYUbVrJfHZ77pxLPORBZLr77YP6UxXYGFy-0PbvcdE0mhRnar6v9rPa0UmIIWMPoh5lmqFONvE8jduRub0P_tZ-xdj0hMuYu2aORvhYPJYntLt0DBzmDvwvMN62rdAtWBuEZx3KPDq04Znm7Lvq_xmmOLZeg70dSU0CFTGIlu5h0cVRYW1DugiqZxtg2GQHNU4DKWPWmKhvPkK6_-t1WUkHTiOIM6kQnCTFIUIBHpIvGtTbryS_M42efF7M_INjH3IyFk53D1XDUIAC8T8M9J5BV5pV8xUodGKm7ChrjD1XU0ChaRBl51-ogxkh9GIPk5f7Ls1hN3-yum9--lefYomqnmYxO01lJOIK4J3qsyE4yRQbIKdP6KD1-ACqrvxbrO2BADhulAMyxbDatwUheJ1fS7TO_SfK6B31ls9bnhv_bgDow41OPsLw8mS6sYgz7hVBB2S7tGtG-PqoTvrQGcONAvMp7KA835q9rZxk6eL0WsYjPu1KOYsqpk96bXdkWZVpQbL0KKkM0u75wjKW7umEndj5mSPiuPbFR71lKPSnnVLE8BYlqIqzI4_ho8gZtePVisk./download [following]
# --2024-05-15 09:59:36--  https://euc1.boxcloud.com/d/1/a1!z_khLHUoRctaMmLlP5dzQ30u3x4hbwFJNOCqskgw5yoNJ1uOPwzXDWLI7FvD0D7TdWt2rJ3FHap6zemcF7sUqKd48FPrLT_QQUJ3M8JxXUCRRY4RNd-szlO3RFA03jcDWTK0SwQcHio3u_P9ub8Bvn1PDc2GvCsfSRqqur-4AZhjIZDLGiVn5mLV8knP4O5uWnorkO2ZqpNIZOvoj0nqH91P1hy5Jfrxfu093_yadsdZFjPKMsUDNd7L1m1aX7A6UTFJ1t_mhYpayur0RCkmSoZgWdwci3BnRMcVUNpKHxIfjMWlIQDhk1Xicg1gEmlr4cCcfwcjWN0j6MR9DDptt36szlVAbMPEy0DodTEUUpjXPg2HLeqTsV3k01sdW7KEEbCwnynKHHccNpRk4ilyN3WyX4EpAb1wkR6o7sDM_84juVH1p8fC9v6Wq4rYxRyPnYz5DFdRCgNN0MA2DvlFaIXbcBNg5IwTqnra932v3f85rLU1yywT-E-EcoIPfSTNFfmXWztdJnqVkWMngijGFSw6NznJPKu48Kj0TlHYIaqlUDSmUqneMICIK_g4l1xV_jtgHYLZQ0vYn_Eh8hqAmXx2XFGdnX3qXOEJwcUiu6tAPlwBToQfbqcz6CFkkz6e7JatbQT4aJK7xZKEPHat6szmKAFPdPE26-WI-ReNtkAt_ql3N90EN2ameA-3KVtvdUENoeI-k5s4iukzzciqi3Wfjcxdw5EUWjgumU4g-_2CP0GiZyyKqzq4y5e73CRmEA1srjP5J-23FStxt7ZbbUEYyfNmMJehAt2h8CqneDbEwGG0zw_sSNj0MhpFenHznxoAFyQMo79i47pjpbYUbVrJfHZ77pxLPORBZLr77YP6UxXYGFy-0PbvcdE0mhRnar6v9rPa0UmIIWMPoh5lmqFONvE8jduRub0P_tZ-xdj0hMuYu2aORvhYPJYntLt0DBzmDvwvMN62rdAtWBuEZx3KPDq04Znm7Lvq_xmmOLZeg70dSU0CFTGIlu5h0cVRYW1DugiqZxtg2GQHNU4DKWPWmKhvPkK6_-t1WUkHTiOIM6kQnCTFIUIBHpIvGtTbryS_M42efF7M_INjH3IyFk53D1XDUIAC8T8M9J5BV5pV8xUodGKm7ChrjD1XU0ChaRBl51-ogxkh9GIPk5f7Ls1hN3-yum9--lefYomqnmYxO01lJOIK4J3qsyE4yRQbIKdP6KD1-ACqrvxbrO2BADhulAMyxbDatwUheJ1fS7TO_SfK6B31ls9bnhv_bgDow41OPsLw8mS6sYgz7hVBB2S7tGtG-PqoTvrQGcONAvMp7KA835q9rZxk6eL0WsYjPu1KOYsqpk96bXdkWZVpQbL0KKkM0u75wjKW7umEndj5mSPiuPbFR71lKPSnnVLE8BYlqIqzI4_ho8gZtePVisk./download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.135
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78396290 (75M) [application/octet-stream]
# Saving to: ‘test_images.npz’
#
# test_images.npz     100%[===================>]  74.76M  23.9MB/s    in 4.0s
#
# 2024-05-15 09:59:41 (18.7 MB/s) - ‘test_images.npz’ saved [78396290/78396290]
#
# --2024-05-15 09:59:41--  https://sussex.box.com/shared/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.144
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a [following]
# --2024-05-15 09:59:41--  https://sussex.box.com/public/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a [following]
# --2024-05-15 09:59:41--  https://sussex.app.box.com/public/static/aulkv3tf2fc0765yqgfm9am87vgn3p8a
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.144
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!RSBeMZA4dh9tOIzGLLO0838P4Ax5yWt03ROOlNCCJ_a0hPnw93VmeMOH5w8Zh3_L9bxuZQDrlAFoVZjIwJGCevELvwFblXOBkvM10eo-y3-B8Mvj4VZ-IZpNxqKHYsMGTcQ1wwExunNhUbN3Rqlbv1Q5gLx4A31YqN_dCcTwAso8IrvxD2bBkhC1NGv-_aAQiiVHqiX9RVJk4K1uTjLGF7DUu86we1RHMl6GO82WL5NtlUa5QGVUuxDi39kTqTSwlm-jshC6mMJPiOgYRbDNBQ26faln5lCbyKaeAvhA6P6dMGiwqBNmjLYkvVqe7lixXq22xvWbJWEckAUw-YkFMssuLV1LelPlj4fygocL1DEPJXOhYmj86edi1Hjis98oM0cXsasE5rSw3c1V8tqvP_F8C0OV5kTnFBFtxsC9QRfSr5tLwWH_VLyDNbfwVVdVg1dB7u9cvpqelsPHpaNPU5lawPdOAE6wnPsKPz3cwOR7rUNcDyQ3NdFRD5H0AlObgxW9_N1f0V4NlxvzoFa-7Yk_WaOiihLdCtDZC_HTuIFoxIQT1nawyEYUqBBgzFxpUIeJeQKHhEnr0QfkGUXtFiTNicTXwTj-I0am4i4V_GMEri8xqgX4gT3uzTu49MemY9cMrS8gsIktKXoL0kK0uNBDp4bpGzedNwWQq6ayCW0St8wDuw9Uc6xGK-um6tbO4FM4eyZWBTzK8DMzJK_LfRg6oruoid37WUJcnU39Aeoq2KUU-55TVTUvSUNVOp_wZ6AKQU9URQl92LRLKn9CAqly1dHLwtb4yv9wL_tROJ0uihsBjqExCllPtlXzGHx0nUR7RCmVH1wBHRvG9z_l0TZqKmo_2wREEVTanl87keDFCx_nphAzhx5wSqZn9-D4nyC-jkjXC7TfbhaeuVrZjEXff06vrWPoJxAxk4pXbB0uHlAByomGD1xVbXoz3-4nf2Voe5E6RfmCORLBjAlV572Fa_o-uhcSogDFpM0SLqyc9YFcm25Zx0rseGRXRUxxf-3PhSdZ8_KdYJWPxAjV0sO3fxTa65JuhFoJWNs-QqCNghGmoxFlVX0qsO9Dvmdh5X-5_zWIV4xusnorA4bWSa934vQXp7HvePMiJ1k8KLxuXgHhsV3EUkCWoLewrCON_g3LLiJJ2huljLD2k0VrUENkl0d6IL28IYAoRy3cIPlMdsfqlaANFQbu82epKEiUwBlUyqGxL83us-zvIAH2Pj1DCaPVnKRafCYlpSrHPY0tV69fKzuA5kzjAv7MCJc1hAOP8LQje4qm1-a0kW5CapJALG0GXNgL0PKfcJpiLTlyGN6NpIyTtIH42FIAICwenV4QAqx6wG9X1xzt4LJTOScaayqgthdo6IxxQ9BNfj8HvP8m5qUY1jAWeHt9F25d1P9OwuzxA0yJdAip/download [following]
# --2024-05-15 09:59:41--  https://euc1.boxcloud.com/d/1/a1!RSBeMZA4dh9tOIzGLLO0838P4Ax5yWt03ROOlNCCJ_a0hPnw93VmeMOH5w8Zh3_L9bxuZQDrlAFoVZjIwJGCevELvwFblXOBkvM10eo-y3-B8Mvj4VZ-IZpNxqKHYsMGTcQ1wwExunNhUbN3Rqlbv1Q5gLx4A31YqN_dCcTwAso8IrvxD2bBkhC1NGv-_aAQiiVHqiX9RVJk4K1uTjLGF7DUu86we1RHMl6GO82WL5NtlUa5QGVUuxDi39kTqTSwlm-jshC6mMJPiOgYRbDNBQ26faln5lCbyKaeAvhA6P6dMGiwqBNmjLYkvVqe7lixXq22xvWbJWEckAUw-YkFMssuLV1LelPlj4fygocL1DEPJXOhYmj86edi1Hjis98oM0cXsasE5rSw3c1V8tqvP_F8C0OV5kTnFBFtxsC9QRfSr5tLwWH_VLyDNbfwVVdVg1dB7u9cvpqelsPHpaNPU5lawPdOAE6wnPsKPz3cwOR7rUNcDyQ3NdFRD5H0AlObgxW9_N1f0V4NlxvzoFa-7Yk_WaOiihLdCtDZC_HTuIFoxIQT1nawyEYUqBBgzFxpUIeJeQKHhEnr0QfkGUXtFiTNicTXwTj-I0am4i4V_GMEri8xqgX4gT3uzTu49MemY9cMrS8gsIktKXoL0kK0uNBDp4bpGzedNwWQq6ayCW0St8wDuw9Uc6xGK-um6tbO4FM4eyZWBTzK8DMzJK_LfRg6oruoid37WUJcnU39Aeoq2KUU-55TVTUvSUNVOp_wZ6AKQU9URQl92LRLKn9CAqly1dHLwtb4yv9wL_tROJ0uihsBjqExCllPtlXzGHx0nUR7RCmVH1wBHRvG9z_l0TZqKmo_2wREEVTanl87keDFCx_nphAzhx5wSqZn9-D4nyC-jkjXC7TfbhaeuVrZjEXff06vrWPoJxAxk4pXbB0uHlAByomGD1xVbXoz3-4nf2Voe5E6RfmCORLBjAlV572Fa_o-uhcSogDFpM0SLqyc9YFcm25Zx0rseGRXRUxxf-3PhSdZ8_KdYJWPxAjV0sO3fxTa65JuhFoJWNs-QqCNghGmoxFlVX0qsO9Dvmdh5X-5_zWIV4xusnorA4bWSa934vQXp7HvePMiJ1k8KLxuXgHhsV3EUkCWoLewrCON_g3LLiJJ2huljLD2k0VrUENkl0d6IL28IYAoRy3cIPlMdsfqlaANFQbu82epKEiUwBlUyqGxL83us-zvIAH2Pj1DCaPVnKRafCYlpSrHPY0tV69fKzuA5kzjAv7MCJc1hAOP8LQje4qm1-a0kW5CapJALG0GXNgL0PKfcJpiLTlyGN6NpIyTtIH42FIAICwenV4QAqx6wG9X1xzt4LJTOScaayqgthdo6IxxQ9BNfj8HvP8m5qUY1jAWeHt9F25d1P9OwuzxA0yJdAip/download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.135
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 809285 (790K) [application/octet-stream]
# Saving to: ‘examples.npz’
#
# examples.npz        100%[===================>] 790.32K   947KB/s    in 0.8s
#
# 2024-05-15 09:59:43 (947 KB/s) - ‘examples.npz’ saved [809285/809285]

# %% [markdown]
# # Check the data downloaded correctly
# If any of these assertions fail, redownload the data

# %%
def confirm_checksum(filename, true_checksum):
  import subprocess
  checksum = subprocess.check_output(['shasum',filename]).decode('utf-8')
  assert checksum.split(' ')[0] == true_checksum, 'Checksum does not match for ' + filename + ' redownload the data.'

confirm_checksum('training_images.npz', 'cf2a926d2165322adcd19d2e88b2eb1cd200ea5c')
confirm_checksum('examples.npz', '0fadc9226e4c0efb4479c5c1bf79491d75828ad3')
confirm_checksum('test_images.npz', 'c7b4b297c7e5c5009706f893ad1fb77a2aa73f95')

# %% [markdown]
# # Load the data

# %%
import numpy as np


# Load the data using np.load
data = np.load('training_images.npz', allow_pickle=True)

# Extract the images
images = data['images']
# and the data points
pts = data['points']

print(images.shape, pts.shape)

test_data = np.load('test_images.npz', allow_pickle=True)
test_images = test_data['images']
print(test_images.shape)

example_data = np.load('examples.npz', allow_pickle=True)
example_images = example_data['images']
print(example_images.shape)
# Out:
# (2811, 256, 256, 3) (2811, 44, 2)
# (554, 256, 256, 3)
# (6, 256, 256, 3)

# %% [markdown]
# # Data Visualisation
# Here's an example of how to display the images and their points

# %%
def visualise_pts(img, pts):
  import matplotlib.pyplot as plt
  plt.imshow(img)
  plt.plot(pts[:, 0], pts[:, 1], '+r')
  plt.show()


for i in range(3):
  idx = np.random.randint(0, images.shape[0])
  visualise_pts(images[idx, ...], pts[idx, ...])

# %% [markdown]
# # Calculating Prediction Error and exporting results

# %%
def euclid_dist(pred_pts, gt_pts):
  """
  Calculate the euclidean distance between pairs of points
  :param pred_pts: The predicted points
  :param gt_pts: The ground truth points
  :return: An array of shape (no_points,) containing the distance of each predicted point from the ground truth
  """
  import numpy as np
  pred_pts = np.reshape(pred_pts, (-1, 2))
  gt_pts = np.reshape(gt_pts, (-1, 2))
  return np.sqrt(np.sum(np.square(pred_pts - gt_pts), axis=-1))

# %%
def save_as_csv(points, location = '.'):
    """
    Save the points out as a .csv file
    :param points: numpy array of shape (no_test_images, no_points, 2) to be saved
    :param location: Directory to save results.csv in. Default to current working directory
    """
    assert points.shape[0]==554, 'wrong number of image points, should be 554 test images'
    assert np.prod(points.shape[1:])==44*2, 'wrong number of points provided. There should be 44 points with 2 values (x,y) per point'
    np.savetxt(location + '/results.csv', np.reshape(points, (points.shape[0], -1)), delimiter=',')

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Normalizing our images
images = images / 255.0
test_images = test_images / 255.0

# %%
# Plot normalized images
for i in range(3):
    idx = np.random.randint(0, images.shape[0])
    visualise_pts(images[idx], pts[idx]

# %%
# Data augmentation process
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
